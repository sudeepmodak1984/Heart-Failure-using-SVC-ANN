# %% [markdown]
# Cardiovascular diseases (CVDs) are the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worlwide. Heart failure is a common event caused by CVDs and this dataset contains 12 features that can be used to predict mortality by heart failure.
#
# Most cardiovascular diseases can be prevented by addressing behavioural risk factors such as tobacco use, unhealthy diet and obesity, physical inactivity and harmful use of alcohol using population-wide strategies.
#
# People with cardiovascular disease or who are at high cardiovascular risk (due to the presence of one or more risk factors such as hypertension, diabetes, hyperlipidaemia or already established disease) need early detection and management wherein a machine learning model can be of great help.

# %% [markdown]
# age: Age of the patient
# anaemia: Haemoglobin level of patient (Boolean)
# creatinine_phosphokinase: Level of the CPK enzyme in the blood (mcg/L)
# diabetes: If the patient has diabetes (Boolean)
# ejection_fraction: Percentage of blood leaving the heart at each contraction
# high_blood_pressure: If the patient has hypertension (Boolean)
# platelets: Platelet count of blood (kiloplatelets/mL)
# serum_creatinine: Level of serum creatinine in the blood (mg/dL)
# serum_sodium: Level of serum sodium in the blood (mEq/L)
# sex: Sex of the patient
# smoking: If the patient smokes or not (Boolean)
# time: Follow-up period (days)
# DEATH_EVENT: If the patient deceased during the follow-up period (Boolean)
# [Attributes having Boolean values: 0 = Negative (No); 1 = Positive (Yes)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn import svm
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
data_df=pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
data_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
sns.countplot(x=data_df['DEATH_EVENT'])
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
data_df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(10,7))
    sns.displot(data_df,x=data_df[i],hue='DEATH_EVENT')
    plt.show()

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(data_df.corr(),annot=True,square=True)
# Out:
# <Axes: >

# %% [markdown]
# Note:
# "time" is the most important feature as it would've been very crucial to get diagnosed early with cardivascular issue so as to get timely treatment thus, reducing the chances of any fatality. (Evident from the inverse relationship)
#
# "serum_creatinine" is the next important feature as serum's (essential component of blood) abundancy in blood makes it easier for heart to function.
#
# "ejection_fraction" has also significant influence on target variable which is expected since it is basically the efficiency of the heart.
#
# Can be seen from the inverse relation pattern that heart's functioning declines with ageing.

# %%
sns.displot(data_df,x=data_df['age'],hue='DEATH_EVENT')

# %%
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(10,7))
    sns.swarmplot(x=data_df["DEATH_EVENT"], y=data_df[i], color="black", alpha=0.7)
    sns.boxenplot(x=data_df["DEATH_EVENT"], y=data_df[i])
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 10.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Plotting "Kernel Density Estimation (kde plot)" of time and age features -  both of which are significant ones.
sns.kdeplot(x=data_df["time"], y=data_df["age"], hue =data_df["DEATH_EVENT"])
# Out:
# <Axes: xlabel='time', ylabel='age'>

# %% [markdown]
# Note:
# With less follow-up days, patients often died only when they aged more.
# More the follow-up days more the probability is, of any fatality.

# %%
# Defining independent and dependent attributes in training and test sets
X=data_df.drop(["DEATH_EVENT"],axis=1)
y=data_df["DEATH_EVENT"]

# %%
# Setting up a standard scaler for the features and analyzing it thereafter
col_names = list(X.columns)
s_scaler = StandardScaler()
X_scaled= s_scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=col_names)
X_scaled.describe()
# Out:
#                 age       anaemia  creatinine_phosphokinase      diabetes  \
# count  2.990000e+02  2.990000e+02                299.000000  2.990000e+02
# mean   5.703353e-16  1.009969e-16                  0.000000  9.060014e-17
# std    1.001676e+00  1.001676e+00                  1.001676  1.001676e+00
# min   -1.754448e+00 -8.711048e-01                 -0.576918 -8.475794e-01
# 25%   -8.281242e-01 -8.711048e-01                 -0.480393 -8.475794e-01
# 50%   -7.022315e-02 -8.711048e-01                 -0.342574 -8.475794e-01
# 75%    7.718891e-01  1.147968e+00                  0.000166  1.179830e+00
# max    2.877170e+00  1.147968e+00                  7.514640  1.179830e+00
#
#        ejection_fraction  high_blood_pressure     platelets  serum_creatinine  \
# count       2.990000e+02           299.000000  2.990000e+02      2.990000e+02
# mean       -3.267546e-17             0.000000  7.723291e-17      1.425838e-16
# std         1.001676e+00             1.001676  1.001676e+00      1.001676e+00
# min        -2.038387e+00            -0.735688 -2.440155e+00     -8.655094e-01
# 25%        -6.841802e-01            -0.735688 -5.208700e-01     -4.782047e-01
# 50%        -7.076750e-03            -0.735688 -1.390846e-02     -2.845524e-01
# 75%         5.853888e-01             1.359272  4.111199e-01      5.926150e-03
# max         3.547716e+00             1.359272  6.008180e+00      7.752020e+00
#
#        serum_sodium           sex       smoking          time
# count  2.990000e+02  2.990000e+02  2.990000e+02  2.990000e+02
# mean  -8.673849e-16 -8.911489e-18 -1.188199e-17 -1.901118e-16
# std    1.001676e+00  1.001676e+00  1.001676e+00  1.001676e+00
# min   -5.363206e+00 -1.359272e+00 -6.876819e-01 -1.629502e+00
# 25%   -5.959961e-01 -1.359272e+00 -6.876819e-01 -7.389995e-01
# 50%    8.503384e-02  7.356882e-01 -6.876819e-01 -1.969543e-01
# 75%    7.660638e-01  7.356882e-01  1.454161e+00  9.387595e-01
# max    2.582144e+00  7.356882e-01  1.454161e+00  1.997038e+00

# %%
colors =["#CD5C5C","#F08080","#FA8072","#E9967A","#FFA07A"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_scaled,palette = colors)
plt.xticks(rotation=60)
plt.show()

# %%
#spliting variables into training and test sets
X_train, X_test, y_train,y_test = train_test_split(X_scaled,y,test_size=0.30,random_state=25)

# %% [markdown]
# **Support Vector Machine for Model building**

# %%
from sklearn.svm import SVC
model=SVC(verbose=True)

# %%
model.fit(X_train,y_train)
# Out:
# [LibSVM]
# SVC(verbose=True)

# %%
# Predicting the test variables
y_pred = model.predict(X_test)

# %%
# Getting the score
model.score (X_test, y_test)
# Out:
# 0.7888888888888889

# %%
# Printing classification report (since there was biasness in target labels)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84        60
#            1       0.69      0.67      0.68        30
#
#     accuracy                           0.79        90
#    macro avg       0.76      0.76      0.76        90
# weighted avg       0.79      0.79      0.79        90

# %%
model.n_features_in_
# Out:
# 12

# %%
model.feature_names_in_
# Out:
# array(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time'],
#       dtype=object)

# %%
model.intercept_
# Out:
# array([0.35740998])

# %%
model.classes_
# Out:
# array([0, 1])

# %% [markdown]
# ANN

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)
# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 25, epochs = 80,callbacks=[early_stopping], validation_split=0.25)
# Out:
# Epoch 1/80
# 7/7 [==============================] - 5s 200ms/step - loss: 0.6928 - accuracy: 0.6026 - val_loss: 0.6911 - val_accuracy: 0.8302
# Epoch 2/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6920 - accuracy: 0.6346 - val_loss: 0.6890 - val_accuracy: 0.8302
# Epoch 3/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6912 - accuracy: 0.6346 - val_loss: 0.6870 - val_accuracy: 0.8302
# Epoch 4/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6904 - accuracy: 0.6346 - val_loss: 0.6850 - val_accuracy: 0.8302
# Epoch 5/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6897 - accuracy: 0.6346 - val_loss: 0.6831 - val_accuracy: 0.8302
# Epoch 6/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6890 - accuracy: 0.6346 - val_loss: 0.6814 - val_accuracy: 0.8302
# Epoch 7/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6879 - accuracy: 0.6346 - val_loss: 0.6795 - val_accuracy: 0.8302
# Epoch 8/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6871 - accuracy: 0.6346 - val_loss: 0.6773 - val_accuracy: 0.8302
# Epoch 9/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6865 - accuracy: 0.6346 - val_loss: 0.6745 - val_accuracy: 0.8302
# Epoch 10/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6846 - accuracy: 0.6346 - val_loss: 0.6709 - val_accuracy: 0.8302
# Epoch 11/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6838 - accuracy: 0.6346 - val_loss: 0.6662 - val_accuracy: 0.8302
# Epoch 12/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6796 - accuracy: 0.6346 - val_loss: 0.6598 - val_accuracy: 0.8302
# Epoch 13/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6741 - accuracy: 0.6346 - val_loss: 0.6507 - val_accuracy: 0.8302
# Epoch 14/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6712 - accuracy: 0.6346 - val_loss: 0.6392 - val_accuracy: 0.8302
# Epoch 15/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6590 - accuracy: 0.6346 - val_loss: 0.6237 - val_accuracy: 0.8302
# Epoch 16/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6485 - accuracy: 0.6346 - val_loss: 0.6015 - val_accuracy: 0.8302
# Epoch 17/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6210 - accuracy: 0.6346 - val_loss: 0.5727 - val_accuracy: 0.8302
# Epoch 18/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6011 - accuracy: 0.6346 - val_loss: 0.5366 - val_accuracy: 0.8302
# Epoch 19/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5954 - accuracy: 0.6346 - val_loss: 0.4992 - val_accuracy: 0.8302
# Epoch 20/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.5654 - accuracy: 0.6346 - val_loss: 0.4604 - val_accuracy: 0.8302
# Epoch 21/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5400 - accuracy: 0.6346 - val_loss: 0.4226 - val_accuracy: 0.8302
# Epoch 22/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.5307 - accuracy: 0.6410 - val_loss: 0.4000 - val_accuracy: 0.8302
# Epoch 23/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5330 - accuracy: 0.6346 - val_loss: 0.3806 - val_accuracy: 0.8302
# Epoch 24/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5215 - accuracy: 0.6474 - val_loss: 0.3682 - val_accuracy: 0.8302
# Epoch 25/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5026 - accuracy: 0.6538 - val_loss: 0.3564 - val_accuracy: 0.8302
# Epoch 26/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5050 - accuracy: 0.6859 - val_loss: 0.3428 - val_accuracy: 0.8302
# Epoch 27/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4898 - accuracy: 0.7179 - val_loss: 0.3302 - val_accuracy: 0.8113
# Epoch 28/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5018 - accuracy: 0.7051 - val_loss: 0.3216 - val_accuracy: 0.8491
# Epoch 29/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4765 - accuracy: 0.7115 - val_loss: 0.3133 - val_accuracy: 0.8302
# Epoch 30/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4882 - accuracy: 0.7436 - val_loss: 0.3102 - val_accuracy: 0.8491
# Epoch 31/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4762 - accuracy: 0.7564 - val_loss: 0.3098 - val_accuracy: 0.9057
# Epoch 32/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4690 - accuracy: 0.6923 - val_loss: 0.3081 - val_accuracy: 0.8868
# Epoch 33/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4482 - accuracy: 0.7308 - val_loss: 0.3083 - val_accuracy: 0.8868
# Epoch 34/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4600 - accuracy: 0.7372 - val_loss: 0.3059 - val_accuracy: 0.8868
# Epoch 35/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4566 - accuracy: 0.7564 - val_loss: 0.3020 - val_accuracy: 0.8868
# Epoch 36/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4683 - accuracy: 0.7115 - val_loss: 0.3013 - val_accuracy: 0.8868
# Epoch 37/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4515 - accuracy: 0.7372 - val_loss: 0.2983 - val_accuracy: 0.8868
# Epoch 38/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.4447 - accuracy: 0.7436 - val_loss: 0.2950 - val_accuracy: 0.8868
# Epoch 39/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4404 - accuracy: 0.7179 - val_loss: 0.2945 - val_accuracy: 0.8868
# Epoch 40/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4818 - accuracy: 0.6731 - val_loss: 0.3022 - val_accuracy: 0.8868
# Epoch 41/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4441 - accuracy: 0.7628 - val_loss: 0.3063 - val_accuracy: 0.8868
# Epoch 42/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4577 - accuracy: 0.7179 - val_loss: 0.3101 - val_accuracy: 0.8868
# Epoch 43/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4084 - accuracy: 0.7692 - val_loss: 0.3129 - val_accuracy: 0.8868
# Epoch 44/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4459 - accuracy: 0.7051 - val_loss: 0.3153 - val_accuracy: 0.8868
# Epoch 45/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4074 - accuracy: 0.7692 - val_loss: 0.3147 - val_accuracy: 0.8868
# Epoch 46/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4252 - accuracy: 0.7500 - val_loss: 0.3121 - val_accuracy: 0.8868
# Epoch 47/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4301 - accuracy: 0.7564 - val_loss: 0.3050 - val_accuracy: 0.8868
# Epoch 48/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3838 - accuracy: 0.8013 - val_loss: 0.2974 - val_accuracy: 0.8868
# Epoch 49/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4142 - accuracy: 0.7628 - val_loss: 0.2933 - val_accuracy: 0.8868
# Epoch 50/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4156 - accuracy: 0.7692 - val_loss: 0.2949 - val_accuracy: 0.8868
# Epoch 51/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3938 - accuracy: 0.7564 - val_loss: 0.2962 - val_accuracy: 0.8679
# Epoch 52/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3752 - accuracy: 0.7885 - val_loss: 0.2968 - val_accuracy: 0.8679
# Epoch 53/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4213 - accuracy: 0.7179 - val_loss: 0.3013 - val_accuracy: 0.8679
# Epoch 54/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4200 - accuracy: 0.7821 - val_loss: 0.3014 - val_accuracy: 0.8679
# Epoch 55/80
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3956 - accuracy: 0.8462 - val_loss: 0.3038 - val_accuracy: 0.8679
# Epoch 56/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4027 - accuracy: 0.8205 - val_loss: 0.3008 - val_accuracy: 0.8679
# Epoch 57/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3948 - accuracy: 0.8397 - val_loss: 0.2979 - val_accuracy: 0.8679
# Epoch 58/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4189 - accuracy: 0.8141 - val_loss: 0.2923 - val_accuracy: 0.8679
# Epoch 59/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4038 - accuracy: 0.8077 - val_loss: 0.2908 - val_accuracy: 0.8679
# Epoch 60/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4073 - accuracy: 0.8269 - val_loss: 0.2943 - val_accuracy: 0.8679
# Epoch 61/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4258 - accuracy: 0.8077 - val_loss: 0.2937 - val_accuracy: 0.8679
# Epoch 62/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3806 - accuracy: 0.7949 - val_loss: 0.2909 - val_accuracy: 0.8679
# Epoch 63/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.3843 - accuracy: 0.8205 - val_loss: 0.2910 - val_accuracy: 0.8679
# Epoch 64/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3514 - accuracy: 0.8397 - val_loss: 0.2928 - val_accuracy: 0.8679
# Epoch 65/80
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3715 - accuracy: 0.8333 - val_loss: 0.2939 - val_accuracy: 0.8679
# Epoch 66/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3663 - accuracy: 0.8333 - val_loss: 0.2922 - val_accuracy: 0.8679
# Epoch 67/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3926 - accuracy: 0.8269 - val_loss: 0.2909 - val_accuracy: 0.8679
# Epoch 68/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3798 - accuracy: 0.8141 - val_loss: 0.2896 - val_accuracy: 0.8679
# Epoch 69/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.3926 - accuracy: 0.8526 - val_loss: 0.2888 - val_accuracy: 0.8679
# Epoch 70/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3378 - accuracy: 0.8462 - val_loss: 0.2878 - val_accuracy: 0.8679
# Epoch 71/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3745 - accuracy: 0.8269 - val_loss: 0.2865 - val_accuracy: 0.8679
# Epoch 72/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.3710 - accuracy: 0.8205 - val_loss: 0.2858 - val_accuracy: 0.8679
# Epoch 73/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3630 - accuracy: 0.8462 - val_loss: 0.2881 - val_accuracy: 0.8679
# Epoch 74/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3657 - accuracy: 0.8397 - val_loss: 0.2883 - val_accuracy: 0.8679
# Epoch 75/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3532 - accuracy: 0.8269 - val_loss: 0.2902 - val_accuracy: 0.8679
# Epoch 76/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3597 - accuracy: 0.8205 - val_loss: 0.2930 - val_accuracy: 0.8679
# Epoch 77/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3752 - accuracy: 0.8205 - val_loss: 0.2961 - val_accuracy: 0.8679
# Epoch 78/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3517 - accuracy: 0.8590 - val_loss: 0.2980 - val_accuracy: 0.8491
# Epoch 79/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3724 - accuracy: 0.8269 - val_loss: 0.2964 - val_accuracy: 0.8679
# Epoch 80/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3671 - accuracy: 0.8333 - val_loss: 0.2924 - val_accuracy: 0.8679

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#CD5C5C", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#FF0000", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#CD5C5C", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']],"#FF0000", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
